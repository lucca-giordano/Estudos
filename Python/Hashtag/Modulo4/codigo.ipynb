# %% [markdown]
# # Automação de Sistemas com Python
#
# ## Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior. O seu trabalho diário como analista é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior.
#
# Link do Drive: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga

# %%
# Passo a passo do desafio
# 1. Entrar no sistema (link do drive)
# 2. Encontrar a base de dados
# 3. Baixar o arquivo
# 4. Calcular os indicadores: Faturamento e Qntd. de Produtos
# 5. Abrir o E-mail
# 6. Enviar as informações

import pyautogui
import pandas
from time import sleep

# %%
# 1.1: Abrir o Google
pyautogui.press("win") # Apertar a tecla Windows
sleep(0.1)
pyautogui.click(1236, 823) # Apertar o botão do Google
sleep(0.2)
pyautogui.click(1360, 678) # Selecionar o perfil no Google

# 1.2: Abrir o sistema
sleep(0.1)
pyautogui.hotkey("ctrl", "t") # Criar uma aba nova no Google
url = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyautogui.typewrite(url, interval=0.001)
pyautogui.press("enter") # Digitarl a URL do sistema e abrir

# 2: Encontrar o arquivo
sleep(2)
pyautogui.doubleClick(399, 482) # Entrar na pasta que contem o arquivo

# 3: Baixar o arquivo
sleep(1)
pyautogui.click(484, 480) # Clicar os 3 pontinhos do arquivo
sleep(0.1)
pyautogui.click(550, 564) # Clicar no botao de download do arquivo

#sleep(0.5)
#pyautogui.hotkey("ctrl", "w")

sleep(2)
print(pyautogui.position())
# Out:
# Point(x=550, y=564)
